# %% [markdown]
# <a href="https://colab.research.google.com/github/chenyq121/760-2022S2/blob/main/dexin_optunaBaselineCNNTest_8bin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mounted to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import numpy as np
import pandas as pd
import torch.nn as nn
import torchvision
import os
import torch.utils.data
import matplotlib.pyplot as plt
from PIL import Image



# data processing 
class ClassifyDataset(torch.utils.data.Dataset):
    def __init__(self,root_path,data_file,img_size=120):
        self.data_files=np.loadtxt(data_file,dtype=np.str)
        self.root_path=root_path
        self.class_list=os.listdir(
            os.path.join(root_path,'')
        )
        self.transforms=torchvision.transforms.Compose(
            [
                torchvision.transforms.Resize((img_size,img_size)), 
                torchvision.transforms.ToTensor()
            ]
        )

    def __getitem__(self, item):
        data_file=self.data_files[item]
        data_file=os.path.join(self.root_path,data_file)
        # get the image
        img=Image.open(data_file).convert('RGB') # three channels
        # get the label(in this case the label is the folder name)
        tmp=data_file.split('/')
        label_name=tmp[-2]
        print("label_name:",label_name)
        label=self.class_list.index(label_name)
        print("label:",label)
        # prepare the images and label
        img=self.transforms(img)
        label=torch.tensor(label)
        print("torch_label:",label)
        return img,label

    def __len__(self):
        return len(self.data_files)



# model building
class CNet(nn.Module):
    def __init__(self,num_classes=21, n_layer = 1, kernel_size = 1):
        super(CNet,self).__init__()
        self.convList = nn.ModuleList()

        for i in range(1, n_layer):
          input = 2 ** (i + 3)
          output = 2 ** (i + 4)
          if i == 1:
            input = 3
            
          self.convList.append(
              nn.Sequential(
                #input, output, kernel size, step, padding
                nn.Conv2d(input, output, kernel_size, 1, padding=1),
                nn.BatchNorm2d(output), # batch normalization
                nn.ReLU()
              )
          )

        self.pool = nn.AvgPool2d(2, 2)
        self.fclayer=nn.Sequential(
                nn.Linear(2 * input, 2 * output),
                nn.ReLU(),
                nn.Linear(2 * output, num_classes)
        )
        self.avg_pool=nn.AdaptiveAvgPool2d((1, 1))
        self.softmax=nn.Softmax(dim=1)

    def forward(self,x):
      x = self.convList[0](x)
      x = self.pool(x)
      for conv in self.convList[1:]:
        x = conv(x)
        x = self.pool(x)
      x = self.avg_pool(x)
      x = torch.flatten(x,1)
      logits=self.fclayer(x)
      prob=self.softmax(logits)
      return logits,prob

    


# training
def training(model,root_path,train_data_file,batch_size,lr, epoch_num):
    # get training data
    train_dataset=ClassifyDataset(root_path,train_data_file)
    train_dataloader=torch.utils.data.DataLoader(train_dataset,batch_size,shuffle=True,num_workers=0)


    # loss function and optimizer
    criterion=nn.CrossEntropyLoss()
    optimizer=torch.optim.Adam(model.parameters(),lr=lr)

    total_loss=[]

    for epoch in range(epoch_num):
        print(epoch+1,"epoch:")
        total_train_loss=0
        res_num=len(train_dataset)
        for data in train_dataloader:

            if (res_num - batch_size) > 0:
                cnt=batch_size
                res_num = res_num - batch_size
            else:
                cnt=res_num
                res_num = 0

            ## GPU
            train_img,train_label=data
            train_img=train_img.to(device)
            train_label=train_label.to(device)

            ## get loss result
            train_logits,train_prob=model(train_img)
            train_loss=criterion.forward(train_logits,train_label)

            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()
            
            train_pred=torch.argmax(train_prob,dim=1)
            print("pre_label:",train_pred)
            train_acc=(train_pred==train_label).float()
            train_acc=torch.mean(train_acc)
            print('loss:',train_loss.item(), 'acc:', train_acc.item())
            total_train_loss=total_train_loss+train_loss*cnt

        total_train_loss=total_train_loss/len(train_dataset)
        total_loss.append(total_train_loss.item())

    state_dict=model.state_dict()
    torch.save(state_dict,'/content/drive/MyDrive/model/60-20-20model_8bin_120-optune.pth')

    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.plot(total_loss)
    plt.legend(['train loss'])
    plt.show()

# test
def test(model,root_path,test_data_file):
    state_dict = torch.load('/content/drive/MyDrive/model/60-20-20model_8bin_120-optune.pth')
    model.load_state_dict(state_dict, strict=False)
    model.eval() # no BatchNormalization and Dropout

    test_dataset=ClassifyDataset(root_path,test_data_file)
    test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size, shuffle=False, num_workers=0)

    criterion = nn.CrossEntropyLoss()

    res_num=len(test_dataset)
    total_acc=0

    for data in test_dataloader:
      with torch.no_grad():

        if (res_num-batch_size)>0:
            cnt=batch_size
            res_num = res_num - batch_size
        else:
            cnt=res_num
            res_num = 0

        test_img,test_label=data
        test_img=test_img.to(device)
        test_label=test_label.to(device)

        test_logits,test_prob=model(test_img)
        test_loss=criterion.forward(test_logits,test_label)

        # Top1 accuracy: correct number/total number
        test_pred = torch.argmax(test_prob, dim=1)
        # print(test_pred)
        # print(test_label)
        print("pre_label:",test_pred)
        print("test_label:",test_label)

        #print(type(test_pred))
        #print(type(test_label))

        px_dict = {"true_label": test_label.cpu().data.numpy(),
                   "pred_label": test_pred.cpu().data.numpy()}
        px = pd.DataFrame(px_dict)

        #test_diff = (test_pred - test_label).float()
        #print('diff:', test_diff)
        test_acc = (test_pred == test_label).float()
        # print(test_acc)
        test_acc = torch.mean(test_acc)
        total_acc = total_acc + test_acc * cnt

        print('loss:',test_loss.item(), 'top1:',test_acc.item() )

    total_acc=total_acc/len(test_dataset)
    # return total_acc.item()
    print('\n')
    print('Top-1 Accuracy:',total_acc.item())

    return px


# def objective(trial):

#     params = {
#               'n_layer': trial.suggest_int('n_layer', 3, 5, step = 2),
#               'kernel_size': trial.suggest_int('kernel_size', 3, 5, step = 2),
#               'lr': trial.suggest_categorical('lr', [0.1, 0.01, 0.001]),
#               'epoch_num': trial.suggest_categorical('epoch_num', [10, 50, 100])
#               }

#     # get model and put model on the device
#     model=CNet(n_layer = params['n_layer'], kernel_size = params['kernel_size'])
#     model = model.to(device)

#     training(model,root_path,train_data_file,batch_size,lr = params['lr'], epoch_num = params['epoch_num'])
#     # torch.cuda.empty_cache()
#     return test(model,root_path,test_data_file)

# %%
# main function
if __name__ == '__main__':

    root_path = r'/content/drive/MyDrive/original/'
    #train_data_file=r'/content/drive/MyDrive/original/8bintrainval.txt'
    test_data_file=r'/content/drive/MyDrive/original/8bintest.txt'
    batch_size=2000
    # lr=best_trial.params['lr'] #learning rate
    # epoch_num=best_trial.params['epoch_num']
    # layers=best_trial.params['n_layer']
    # kernals=best_trial.params['kernel_size']
    # lr=0.01 #learning rate
    # epoch_num=10
    layers=5
    kernals=5
    device='cuda:0'
    # # get model and put model on the device
    model=CNet(n_layer = layers, kernel_size = kernals)
    model.to(device)

    #training(model,root_path,train_data_file,batch_size,lr,epoch_num)
    torch.cuda.empty_cache()
    px = test(model, root_path,test_data_file)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: DeprecationWarning: `np.str` is a deprecated alias for the builtin `str`. To silence this warning, use `str` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.str_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   app.launch_new_instance()
# Streaming output truncated to the last 5000 lines.
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# ...
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin4
# label: 3
# torch_label: tensor(3)
# label_name: bin7
# label: 6
# torch_label: tensor(6)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin3
# label: 2
# torch_label: tensor(2)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin5
# label: 4
# torch_label: tensor(4)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin1
# label: 0
# torch_label: tensor(0)
# label_name: bin8
# label: 7
# torch_label: tensor(7)
# label_name: bin6
# label: 5
# torch_label: tensor(5)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# label_name: bin2
# label: 1
# torch_label: tensor(1)
# pre_label: tensor([3, 0, 2,  ..., 0, 3, 2], device='cuda:0')
# test_label: tensor([5, 7, 1,  ..., 1, 1, 1], device='cuda:0')
# loss: 2.2494192123413086 top1: 0.1350427269935608
#
#
# Top-1 Accuracy: 0.1350427269935608

# %%
px
# Out:
#       true_label  pred_label
# 0              5           3
# 1              7           0
# 2              1           2
# 3              6           6
# 4              0           7
# ...          ...         ...
# 1750           7           7
# 1751           5           3
# 1752           1           0
# 1753           1           3
# 1754           1           2
#
# [1755 rows x 2 columns]

# %%
ids = list()
with open('/content/drive/MyDrive/original/4bintest.txt', 'r') as f:
  id_lst = f.readlines()
  for each in id_lst:
    id = each.split("/")[1].split(".")[0]
    ids.append(id)
print(ids)
# Out:
# ['6087', '9618', '4809', '2828', '2057', '385', '9134', '5355', '8804', '7952', '4009', '4229', '8118', '7466', '1364', '3772', '5717', '45', '4200', '4921', '8892', '7331', '7382', '9420', '8217', '193', '1439', '3554', '9255', '3251', '3378', '8531', '7233', '9152', '7181', '7036', '5835', '7992', '267', '2368', '105', '1471', '800', '3207', '9688', '8877', '7815', '5391', '6890', '3512', '9327', '4754', '6303', '7555', '5279', '9268', '1495', '4670', '8059', '4018', '8747', '5000', '6336', '8838', '4979', '4863', '3371', '6167', '7983', '1179', '4767', '3777', '5405', '2814', '1883', '9476', '5599', '7943', '4883', '9736', '4360', '7390', '6813', '1631', '5690', '2221', '266', '7454', '3706', '4435', '6108', '3717', '4580', '6908', '1147', '8137', '9852', '7422', '5645', '2588', '1535', '2367', '3874', '377', '6275', '1223', '8053', '6481', '7226', '7446', '9385', '3337', '8907', '7808', '1547', '6148', '2968', '2951', '5384', '8399', '8753', '3278', '8032', '5893', '6257', '5323', '6641', '6415', '3543', '6822', '7213', '4515', '4551', '6157', '3029', '9678', '440', '9272', '9811', '6335', '2804', '1302', '339', '7364', '8523', '4429', '2986', '526', '6310', '2173', '7340', '6702', '5967', '4740', '3683', '4119', '5816', '5395', '1330', '6293', '9017', '2980', '1080', '9797', '4609', '9876', '1634', '8124', '2331', '8483', '2165', '184', '7797', '4050', '4926', '6351', '5472', '8537', '2963', '5199', '7100', '7284', '7997', '1830', '9034', '4698', '6500', '6624', '1384', '1448', '8155', '5366', '3045', '3160', '4443', '9709', '5781', '6292', '5670', '4446', '3394', '3613', '6353', '6764', '5828', '8760', '5520', '6468', '4090', '6435', '4666', '5586', '6940', '8842', '3392', '696', '8482', '1584', '6246', '2065', '3201', '388', '7125', '7302', '9395', '8239', '2051', '4106', '8437', '9581', '7855', '753', '572', '8516', '3227', '6818', '9258', '3352', '3484', '5317', '9686', '4984', '5327', '4093', '3923', '2446', '4573', '6645', '6204', '8184', '2263', '3795', '5701', '9892', '9371', '9970', '5259', '1331', '5221', '1295', '1354', '3937', '7303', '4960', '72', '992', '4123', '2126', '6689', '5083', '3212', '1696', '5849', '4933', '9966', '9589', '9422', '5952', '1206', '5521', '3752', '8234', '9198', '8816', '7953', '3480', '7513', '260', '7972', '1781', '7256', '474', '2098', '8863', '7380', '1355', '174', '5422', '1113', '8970', '1002', '9873', '3691', '4728', '5075', '5580', '3193', '4461', '8421', '7235', '3381', '6695', '7769', '9819', '7698', '8870', '719', '5341', '741', '9468', '7627', '562', '3541', '2947', '7336', '1435', '1876', '1605', '5008', '9413', '9596', '9464', '6366', '4554', '7928', '6472', '6960', '6135', '2382', '586', '4667', '5089', '9919', '7433', '8635', '9113', '6388', '4239', '7971', '8622', '2547', '1519', '7860', '2778', '9787', '3526', '8481', '7145', '3189', '4305', '6357', '8592', '9074', '4335', '2838', '2314', '2030', '8236', '9036', '8093', '7136', '1560', '4033', '7615', '7337', '9710', '8788', '4584', '8345', '4326', '150', '5281', '1525', '2285', '4744', '5943', '5210', '7096', '6536', '5837', '7809', '3559', '9591', '1957', '4760', '7869', '4044', '6059', '6563', '3994', '6557', '5610', '5617', '2955', '9305', '1226', '6691', '4447', '5125', '8362', '3901', '3856', '6318', '4301', '2130', '4685', '9297', '2893', '426', '2979', '5115', '4700', '2772', '382', '1971', '3271', '4888', '3665', '3892', '9584', '9430', '4048', '5040', '9133', '5697', '3186', '5187', '9462', '4125', '9717', '4259', '189', '6372', '6156', '3252', '3570', '3470', '6560', '7857', '1931', '7577', '8105', '3440', '6587', '69', '9929', '2993', '5805', '5721', '8776', '6238', '9871', '4276', '6016', '8690', '5573', '1559', '8647', '2348', '7428', '9259', '7332', '6713', '8177', '9953', '5311', '7633', '7149', '2067', '2346', '6607', '2839', '4108', '5803', '5047', '7719', '8084', '6493', '8287', '2012', '5421', '9325', '2810', '304', '9328', '2272', '8835', '4388', '4385', '2003', '5957', '2416', '281', '1746', '3 ...

# %%
px.insert(0, "ID", ids,True)

# %%
px["pred_label"].unique()
# Out:
# array([3, 0, 2, 6, 7, 4, 1, 5])

# %%
px["true_label"].unique()
# Out:
# array([5, 7, 1, 6, 0, 4, 2, 3])

# %%
px["difference"] = abs(px["pred_label"] - px["true_label"])

# %%
px
# Out:
#         ID  true_label  pred_label  difference
# 0     6087           5           3           2
# 1     9618           7           0           7
# 2     4809           1           2           1
# 3     2828           6           6           0
# 4     2057           0           7           7
# ...    ...         ...         ...         ...
# 1750  9233           7           7           0
# 1751  3978           5           3           2
# 1752  8122           1           0           1
# 1753  5903           1           3           2
# 1754  2875           1           2           1
#
# [1755 rows x 4 columns]

# %%
px.to_csv(path_or_buf="/content/drive/MyDrive/eight_bin_diff_result.csv", index=False)

# %%
res = px[px["difference"]==0]

# %%
len(res)
# Out:
# 237

# %%
correct_id = res["ID"]

# %%
correct_id.to_list()
# Out:
# ['2828',
#  '7952',
#  '8118',
#  '7382',
#  '3251',
#  '7181',
#  '7036',
#  '5835',
#  '800',
#  '8877',
#  '4754',
#  '1495',
#  '4670',
#  '8059',
#  '7943',
#  '9736',
#  '7390',
#  '7454',
#  '4580',
#  '6415',
#  '7213',
#  '7364',
#  '1330',
#  '8124',
#  '8483',
#  '2165',
#  '7100',
#  '6500',
#  '5366',
#  '3160',
#  '4666',
#  '7302',
#  '8516',
#  '9686',
#  '72',
#  '1696',
#  '2098',
#  '3193',
#  '8421',
#  '7698',
#  '9468',
#  '562',
#  '9413',
#  '7433',
#  '6388',
#  '4239',
#  '2547',
#  '2778',
#  '7145',
#  '8093',
#  '7337',
#  '9710',
#  '8345',
#  '6536',
#  '4760',
#  '7869',
#  '2772',
#  '4888',
#  '9462',
#  '189',
#  '1931',
#  '7577',
#  '3440',
#  '69',
#  '7633',
#  '2346',
#  '281',
#  '4851',
#  '49',
#  '201',
#  '1726',
#  '1942',
#  '9976',
#  '7293',
#  '518',
#  '7188',
#  '6019',
#  '7764',
#  '6716',
#  '8383',
#  '5853',
#  '8078',
#  '4361',
#  '3537',
#  '5293',
#  '8994',
#  '2395',
#  '5051',
#  '7768',
#  '9380',
#  '7818',
#  '3540',
#  '1685',
#  '2300',
#  '5592',
#  '5371',
#  '5195',
#  '3669',
#  '8096',
#  '4491',
#  '3807',
#  '4196',
#  '3816',
#  '6116',
#  '2219',
#  '4362',
#  '6142',
#  '4096',
#  '6387',
#  '7251',
#  '1470',
#  '4579',
#  '3906',
#  '2509',
#  '206',
#  '5352',
#  '3840',
#  '5833',
#  '805',
#  '7576',
#  '8558',
#  '5954',
#  '9136',
#  '5817',
#  '8871',
#  '4832',
#  '5790',
#  '3693',
#  '9092',
#  '3361',
#  '8140',
#  '8514',
#  '3762',
#  '243',
#  '3177',
#  '8839',
#  '9438',
#  '8180',
#  '2042',
#  '4066',
#  '2005',
#  '1800',
#  '127',
#  '3298',
#  '2495',
#  '8722',
#  '1852',
#  '3818',
#  '3694',
#  '784',
#  '2568',
#  '7559',
#  '732',
#  '1831',
#  '8349',
#  '5985',
#  '1241',
#  '1254',
#  '3194',
#  '3195',
#  '4857',
#  '1626',
#  '2210',
#  '508',
#  '1965',
#  '2014',
#  '7738',
#  '2609',
#  '4837',
#  '6873',
#  '1908',
#  '2294',
#  '7333',
#  '1715',
#  '5342',
#  '9613',
#  '7553',
#  '2265',
#  '9997',
#  '7893',
#  '1309',
#  '9473',
#  '2882',
#  '8179',
#  '7982',
#  '5446',
#  '8827',
#  '6127',
#  '9319',
#  '9148',
#  '9409',
#  '5276',
#  '9403',
#  '8801',
#  '8643',
#  '5333',
#  '4907',
#  '9884',
#  '4918',
#  '5459',
#  '5752',
#  '7416',
#  '8544',
#  '3797',
#  '8550',
#  '7219',
#  '7430',
#  '9084',
#  '5880',
#  '662',
#  '3059',
#  '3176',
#  '9026',
#  '9641',
#  '4564',
#  '8913',
#  '6979',
#  '2613',
#  '8669',
#  '3403',
#  '9153',
#  '6763',
#  '5582',
#  '7143',
#  '8083',
#  '8879',
#  '9287',
#  '466',
#  '5265',
#  '3329',
#  '9288',
#  '2332',
#  '1058',
#  '4927',
#  '6975',
#  '3742',
#  '9233']
